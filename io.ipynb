# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
IData=pd.read_csv('IceCreamData.csv')
IData.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
plt.figure(figsize = (13,7))
sns.regplot(x = 'Temperature' , y = 'Revenue', data = IData)
# Out:
# <Axes: xlabel='Temperature', ylabel='Revenue'>

# %%
X=IData['Temperature']
y=IData['Revenue']

# %%
x=np.array(X)
y=np.array(y)

# %%
X = np.array(X).reshape(-1, 1)
y = np.array(y).reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
y_train.shape
# Out:
# (350, 1)

# %%
X_test.shape
# Out:
# (150, 1)

# %%
y_test.shape
# Out:
# (150, 1)

# %%
X_train.shape
# Out:
# (350, 1)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (350, 1)
# y_train shape: (350, 1)
# X_test shape: (150, 1)
# y_test shape: (150, 1)

# %%
from sklearn.linear_model import LinearRegression
a = LinearRegression(fit_intercept = True)
a.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff (m):', a.coef_)
print('Linear Model Intercept (b):', a.intercept_)
# Out:
# Linear Model Coeff (m): [[21.57349265]]
# Linear Model Intercept (b): [41.24521602]

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, a.predict(X_train), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated and  Temperature  for ICE CREAM PALOR')
# Out:
# Text(0.5, 1.0, 'Revenue Generated and  Temperature  for ICE CREAM PALOR')

# %%
accuracy_LinearRegression = a.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.9729915939968328

# %%
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, a.predict(X_test), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated and  Temperature ')
# Out:
# Text(0.5, 1.0, 'Revenue Generated and  Temperature ')

# %%
Temp = np.array([30])
Temp = Temp.reshape(-1,1)

Revenue = a.predict(Temp)
print('Revenue Predictions =', Revenue)
# Out:
# Revenue Predictions = [[688.4499955]]
